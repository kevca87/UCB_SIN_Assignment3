# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('movements_0401_1300.csv')

# %%
df[df['Player']=='PC']
# Out:
#     Unnamed: 0 Player Movements      Times
# 1            1     PC        E3  -0.428015
# 3            3     PC        G3  -0.993043
# 5            5     PC        E1  -1.777898
# 7            7     PC        B4  -1.742124
# 9            9     PC        D6  -3.899521
# 11          11     PC        C3  -6.359123
# 13          13     PC        C1  -3.933159
# 15          15     PC        G6  -5.818600
# 17          17     PC        D2  -7.729351
# 19          19     PC        G1  -5.187962
# 21          21     PC        E7 -11.844189
# 23          23     PC        A6  -9.801615
# 25          25     PC        D7  -4.621255
# 27          27     PC        H7  -0.933577
# 29          29     PC        C8  -3.801332
# 31          31     PC        B8  -5.603459
# 33          33     PC        B6  -7.481778
# 35          35     PC        B3 -14.723210
# 37          37     PC        A3 -14.276552
# 39          39     PC        H4 -11.838155
# 41          41     PC        A7 -12.267598
# ...

# %%
fig, ax = plt.subplots(figsize=(6, 5))
#ax.set_xticklabels([0.99,0.97,0.95])
plt.boxplot(df[df['Player']=='PC']['Times'])
plt.show()

# %%
df = pd.read_csv('movements_PC1_PC2_Depth4.csv')

# %%
df
# Out:
#     Unnamed: 0 Player Movements     Times  In-FavorTiles  Heuristic
# 0            0    PC2        C4  0.290996              4          6
# 1            1    PC1        E3  0.335230              3         -4
# 2            2    PC2        F2  0.717335              5          8
# 3            3    PC1        B4  1.030079              5         -8
# 4            4    PC2        E6  1.312575              6          8
# 5            5    PC1        G1  0.930029              6         -7
# 6            6    PC2        A4  0.833313              8          6
# 7            7    PC1        E7  0.373018              7         -6
# 8            8    PC2        F3  1.509908              7          8
# 9            9    PC1        B3  2.183155              9        -11
# 10          10    PC2        E8  4.969303              9         12
# 11          11    PC1        F4  2.300918             10         -9
# 12          12    PC2        A2  2.852032             10          9
# ...

# %%
fig, ax = plt.subplots(figsize=(6, 5))
#ax.set_xticklabels([0.99,0.97,0.95])
plt.boxplot(df[df['Player']=='PC1']['Times'])
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 5))
#ax.set_xticklabels([0.99,0.97,0.95])
plt.boxplot(df[df['Player']=='PC2']['Times'])
plt.show()

# %%
df = pd.read_csv('movements_PC1_PC2_Depth4_OrderChange.csv')
